# %% [markdown]
# # Mask R-CNN - Train on Shapes Dataset
#
#
# This notebook shows how to train Mask R-CNN on your own dataset. To keep things simple we use a synthetic dataset of shapes (squares, triangles, and circles) which enables fast training. You'd still need a GPU, though, because the network backbone is a Resnet101, which would be too slow to train on a CPU. On a GPU, you can start to get okay-ish results in a few minutes, and good results in less than an hour.
#
# The code of the *Shapes* dataset is included below. It generates images on the fly, so it doesn't require downloading any data. And it can generate images of any size, so we pick a small image size to train faster.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !sudo update-alternatives --config python3

# %%
# !cp -r /usr/local/lib/python3.7/dist-packages /usr/local/lib/python3.6/

# %%
# !apt-get --purge remove cuda nvidia* libnvidia-*
# !dpkg -l | grep cuda- | awk '{print $2}' | xargs -n1 dpkg --purge
# !apt-get remove cuda-*
# !apt autoremove
# !apt-get update

# %% [markdown]
# Install Cuda8.0

# %%
# !wget https://developer.nvidia.com/compute/cuda/8.0/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb
# !dpkg -i cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb
# !apt-get update
# !apt-get install cuda=8.0.61-1

# %% [markdown]
# Install Cuda10.0

# %%
#Download CUDA 10.0
# !wget  --no-clobber https://developer.nvidia.com/compute/cuda/10.0/Prod/local_installers/cuda-repo-ubuntu1804-10-0-local-10.0.130-410.48_1.0-1_amd64
#install CUDA kit dpkg
# !dpkg -i cuda-repo-ubuntu1804-10-0-local-10.0.130-410.48_1.0-1_amd64
# !sudo apt-key add /var/cuda-repo-10-0-local-10.0.130-410.48/7fa2af80.pub
# !apt-get update
# !apt-get install **cuda-10-0**
# !nvcc --version

# %%
# !sudo cp /content/drive/MyDrive/CGMH/cudnn.h /usr/local/cuda/include
# !cat /usr/local/cuda/include/cudnn.h | grep CUDNN_MAJOR -A 2
# Out:
# #define CUDNN_MAJOR 7
# #define CUDNN_MINOR 5
# #define CUDNN_PATCHLEVEL 0
# --
# #define CUDNN_VERSION (CUDNN_MAJOR * 1000 + CUDNN_MINOR * 100 + CUDNN_PATCHLEVEL)
#
# #include "driver_types.h"

# %%
# !pip uninstall tensorflow -y
#!pip install gast==0.2.2
# !pip install tensorflow-gpu==1.15
# !apt install --allow-change-held-packages libcudnn7=7.4.1.5-1+cuda10.0
# !pip install keras==2.0.8

# %%
# %cd /content/drive/MyDrive
# !git clone https://github.com/matterport/Mask_RCNN.git
# Out:
# /content/drive/MyDrive
# fatal: destination path 'Mask_RCNN' already exists and is not an empty directory.

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 1.15.0

# %%
import tensorflow as tf
print(tf.__version__)
# %cd /content/drive/MyDrive/Mask_RCNN
# !pip install -r requirements.txt
# !python setup.py install

# %%
#!pip install scipy
# !pip install -U scikit-image==0.16.2

# %%
# %cd /content/drive/MyDrive/Mask_RCNN
# !git clone https://github.com/cocodataset/cocoapi
# %cd /content/drive/MyDrive/Mask_RCNN/cocoapi/PythonAPI
# !python setup.py install

# %%
# %cd /content/drive/MyDrive/Mask_RCNN
# !python setup.py install

# %%
import os
import sys
import random
import math
import re
import time
import numpy as np
import cv2
import matplotlib
import matplotlib.pyplot as plt
import tensorflow as tf
import yaml

from mrcnn.config import Config
#import utils
from mrcnn import model as modellib,utils
from mrcnn import visualize
import yaml
from mrcnn.model import log
from PIL import Image
# Root directory of the project
ROOT_DIR = os.path.abspath("/content/drive/MyDrive/Mask_RCNN")

# Import Mask RCNN
#sys.path.append(ROOT_DIR)  # To find local version of the library

# %matplotlib inline 

os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# Root directory of the project
#ROOT_DIR = os.getcwd()

#ROOT_DIR = os.path.abspath("../")
# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "logs")

iter_num=0

# Local path to trained weights file
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")
# Download COCO trained weights from Releases if needed
if not os.path.exists(COCO_MODEL_PATH):
    utils.download_trained_weights(COCO_MODEL_PATH)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Configurations

# %%
class ShapesConfig(Config):
    """Configuration for training on the toy shapes dataset.
    Derives from the base Config class and overrides values specific
    to the toy shapes dataset.
    """
    def __init__(self, num_classes):
      self.NUM_CLASSES = num_classes
      super().__init__()
    # Give the configuration a recognizable name
    NAME = "shapes"

    # Train on 1 GPU and 8 images per GPU. We can put multiple images on each
    # GPU because the images are small. Batch size is 8 (GPUs * images/GPU).
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

    # Number of classes (including background)
    NUM_CLASSES = 1 + 3  # background + ears

    # Use small images for faster training. Set the limits of the small side
    # the large side, and that determines the image shape.
    IMAGE_MIN_DIM = 512
    IMAGE_MAX_DIM = 512

    IMAGE_CHANNEL_COUNT = 1
    MEAN_PIXEL = np.array([123.7])
    # Use smaller anchors because our image and objects are small
    #RPN_ANCHOR_SCALES = (8*6, 16*6, 32*6, 64*6, 128*6)  # anchor side in pixels
    RPN_ANCHOR_SCALES =(32,64,128,256,512)
    # Reduce training ROIs per image because the images are small and have
    # few objects. Aim to allow ROI sampling to pick 33% positive ROIs.
    TRAIN_ROIS_PER_IMAGE = 100

    # Use a small epoch since the data is simple
    STEPS_PER_EPOCH = 100

    # use small validation steps since the epoch is small
    VALIDATION_STEPS = 50
    
    # Accoring to CSDN 79140840 defin a global val iter_num
    # iter_num = 0
    
config = ShapesConfig(num_classes=4)
#config = ShapesConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            1
# IMAGE_MAX_DIM                  512
# IMAGE_META_SIZE                15
# IMAGE_MIN_DIM                  512
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [512 512   1]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           shapes
# NUM_CLASSES                    4
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                100
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           100
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %% [markdown]
# ## Notebook Preferences

# %%
def get_ax(rows=1, cols=1, size=8):
    """Return a Matplotlib Axes array to be used in
    all visualizations in the notebook. Provide a
    central point to control graph sizes.
    
    Change the default size attribute to control the size
    of rendered images
    """
    _, ax = plt.subplots(rows, cols, figsize=(size*cols, size*rows))
    return ax

# %% [markdown]
# ## Dataset
#
# Create a synthetic dataset
#
# Extend the Dataset class and add a method to load the shapes dataset, `load_shapes()`, and override the following methods:
#
# * load_image()
# * load_mask()
# * image_reference()

# %%
# Define your own train class
class DrugDataset(utils.Dataset):
    # 得到该图中有多少个实例（物体）
    def get_obj_index(self, image):
        n = np.max(image)
        return n

    # 解析labelme中得到的yaml文件，从而得到mask每一层对应的实例标签
    def from_yaml_get_class(self, image_id):
        info = self.image_info[image_id]
        with open(info['yaml_path']) as f:
            temp = yaml.load(f.read(), Loader=yaml.FullLoader)
            labels = temp['label_names']
            del labels[0]
        return labels

    # 重新写draw_mask
    def draw_mask(self, num_obj, mask, image,image_id):
        #print("draw_mask-->",image_id)
        #print("self.image_info",self.image_info)
        info = self.image_info[image_id]
        #print("info-->",info)
        #print("info[width]----->",info['width'],"-info[height]--->",info['height'])
        for index in range(num_obj):
            for i in range(info['width']):
                for j in range(info['height']):
                    #print("image_id-->",image_id,"-i--->",i,"-j--->",j)
                    #print("info[width]----->",info['width'],"-info[height]--->",info['height'])
                    at_pixel = image.getpixel((i, j))
                    if at_pixel == index + 1:
                        mask[j, i, index] = 1
        return mask

    # 重新写load_shapes，里面包含自己的自己的类别
    # 并在self.image_info信息中添加了path、mask_path 、yaml_path
    # yaml_pathdataset_root_path = "/tongue_dateset/"
    # img_floder = dataset_root_path + "rgb"
    # mask_floder = dataset_root_path + "mask"
    # dataset_root_path = "/tongue_dateset/"
    def load_shapes(self, count, img_floder, mask_floder, imglist, dataset_root_path):
        """Generate the requested number of synthetic images.
        count: number of images to generate.
        height, width: the size of the generated images.
        """
        # Add classes
        self.add_class("shapes", 1, "cylindrical") # ears
        self.add_class("shapes", 2, "varicose")
        self.add_class("shapes", 3, "cystic")

        for i in range(count):
            # 获取图片宽和高

            filestr = imglist[i].split(".")[0]
            #print(imglist[i],"-->",cv_img.shape[1],"--->",cv_img.shape[0])
            #print("id-->", i, " imglist[", i, "]-->", imglist[i],"filestr-->",filestr)
            # filestr = filestr.split("_")[1]
            mask_path = mask_floder + "/" + filestr + ".png"
            yaml_path = dataset_root_path + "labelme_json/" + filestr + "_json/info.yaml"
            print(dataset_root_path + "labelme_json/" + filestr + "_json/img.png")
            cv_img = cv2.imread(dataset_root_path + "labelme_json/" + filestr + "_json/img.png")

            self.add_image("shapes", image_id=i, path=img_floder + "/" + imglist[i],
                           width=cv_img.shape[1], height=cv_img.shape[0], mask_path=mask_path, yaml_path=yaml_path)

      # 重写load_mask
    def load_mask(self, image_id):
          """Generate instance masks for shapes of the given image ID.
          """
          global iter_num
          print("image_id",image_id)
          info = self.image_info[image_id]
          count = 1  # number of object
          img = Image.open(info['mask_path'])
          num_obj = self.get_obj_index(img)
          mask = np.zeros([info['height'], info['width'], num_obj], dtype=np.uint8)
          mask = self.draw_mask(num_obj, mask, img,image_id)
          occlusion = np.logical_not(mask[:, :, -1]).astype(np.uint8)
          for i in range(count - 2, -1, -1):
              mask[:, :, i] = mask[:, :, i] * occlusion

              occlusion = np.logical_and(occlusion, np.logical_not(mask[:, :, i]))
          labels = []
          labels = self.from_yaml_get_class(image_id)
          labels_form = []
          for i in range(len(labels)):
              if labels[i].find("cylindrical") != -1:
                  # print "box"
                labels_form.append("cylindrical")
              elif labels[i].find("varicose") != -1:
                  # print "box"
                labels_form.append("varicose")
              elif labels[i].find("cystic") != -1:
                  # print "box"
                labels_form.append("cystic")

          class_ids = np.array([self.class_names.index(s) for s in labels_form])
          return mask, class_ids.astype(np.int32)


def get_ax(rows=1, cols=1, size=8):
    """Return a Matplotlib Axes array to be used in
    all visualizations in the notebook. Provide a
    central point to control graph sizes.

    Change the default size attribute to control the size
    of rendered images
    """
    _, ax = plt.subplots(rows, cols, figsize=(size * cols, size * rows))
    return ax

# %%
#基础设置
dataset_root_path="/content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/"
img_floder = dataset_root_path + "pic"
mask_floder = dataset_root_path + "cv2_mask"
#yaml_floder = dataset_root_path
imglist = os.listdir(img_floder)
count = len(imglist)

# %%
#train与val数据集准备
dataset_train = DrugDataset()
dataset_train.load_shapes(count, img_floder, mask_floder, imglist,dataset_root_path)
dataset_train.prepare()
#print("dataset_train-->",dataset_train._image_ids)

dataset_val = DrugDataset()
dataset_val.load_shapes(7, img_floder, mask_floder, imglist,dataset_root_path)
dataset_val.prepare()
# Out:
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/13-3_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/11-15_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/11-3_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/15-30_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/11-17_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/15-29_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/15-10_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/14-20_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/1-22_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/16-5_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/11-14_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/16-12_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/14-19_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/18-10_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/13-5_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/11-25_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/15-24_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/10-21_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/11-32_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/14-21_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/10-10_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/16-13_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/11-19_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/10-19_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/15-25_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/12-9_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/10-26_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/11-7_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/16-23_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/15-7_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/13-6_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/11-11_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/1-2_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/12-4_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/12-11_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/1-24_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/17-13_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/15-12_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/16-14_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/15-11_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/10-11_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/15-31_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/10-16_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/17-19_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/10-6_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/15-28_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/10-13_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/16-16_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/10-17_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/11-30_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/1-20_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/15-5_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/15-8_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/10-15_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/10-3_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/17-10_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/1-11_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/10-18_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/16-7_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/16-10_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/16-3_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/17-12_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/11-21_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/10-5_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/15-2_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/16-20_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/13-8_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/10-8_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/14-17_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/15-3_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/10-20_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/16-8_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/11-1_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/11-5_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/12-6_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/7-17_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/19-35_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/22-16_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/4-42_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/20-16_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/20-12_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/4-17_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/21-14_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/8-38_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/9-17_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/23-18_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/5-5_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/22-36_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/22-19_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/20-47_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/21-27_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/5-27_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/2-3_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/9-13_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/6-9_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/18-4_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/23-12_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/5-10_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/22-25_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/20-25_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/4-26_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/21-38_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/9-11_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/8-27_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/4-30_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/22-20_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/7-10_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/21-5_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/8-34_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/8-1_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/9-25_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/7-5_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/23-10_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/9-10_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/20-41_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/4-13_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/5-30_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/21-22_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/22-26_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/20-46_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/7-34_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/8-22_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/5-32_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/8-29_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/18-7_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/20-19_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/23-9_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/8-9_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/21-25_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/7-12_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/7-28_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/18-17_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/6-4_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/3-19_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/4-35_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/21-13_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/21-35_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/20-44_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/8-3_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/3-27_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/3-24_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/8-21_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/9-18_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/7-8_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/21-37_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/22-27_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/19-37_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/23-3_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/21-32_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/8-23_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/20-26_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/23-4_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/23-2_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/22-35_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/23-17_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/6-13_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/23-20_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/5-36_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/22-28_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/18-2_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/22-29_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/20-29_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/9-20_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/18-13_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/6-11_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/23-16_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/21-10_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/5-8_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/5-28_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/22-23_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/2-14_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/20-20_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/21-34_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/21-8_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/8-25_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/5-13_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/3-3_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/5-31_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/5-7_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/6-2_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/6-17_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/2-8_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/21-36_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/19-30_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/21-17_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/5-20_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/8-7_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/7-27_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/23-19_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/20-32_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/3-14_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/19-34_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/23-8_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/18-11_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/20-11_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/21-39_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/21-16_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/6-24_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/18-16_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/21-18_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/7-36_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/21-24_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/6-6_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/8-33_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/18-27_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/18-20_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/20-24_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/19-33_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/22-21_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/7-32_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/22-32_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/19-39_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/6-22_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/9-24_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/5-34_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/2-6_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/7-22_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/8-12_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/23-21_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/19-41_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/5-25_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/6-18_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/3-15_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/8-17_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/7-13_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/23-1_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/21-19_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/4-33_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/22-22_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/8-31_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/3-21_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/9-8_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/21-28_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/4-27_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/21-9_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/21-21_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/21-26_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/4-32_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/6-15_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/23-14_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/3-5_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/22-30_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/5-40_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/4-39_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/20-18_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/22-24_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/23-15_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/19-26_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/21-33_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/20-34_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/23-6_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/8-5_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/19-27_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/21-12_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/19-13_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/22-33_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/23-11_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/20-30_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/6-20_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/23-7_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/9-14_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/18-5_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/21-30_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/20-27_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/5-4_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/21-40_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/8-36_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/23-13_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/21-31_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/22-34_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/18-23_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/5-22_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/21-29_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/7-30_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/21-23_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/18-25_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/21-20_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/7-15_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/20-22_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/20-17_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/13-3_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/11-15_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/11-3_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/15-30_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/11-17_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/15-29_json/img.png
# /content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/15-10_json/img.png

# %%
# Load and display random samples
image_ids = np.random.choice(dataset_train.image_ids, 4)
#image_ids = dataset_train.image_ids[83]
print(image_ids)
for image_id in image_ids:
    image = dataset_train.load_image(image_id)
    mask, class_ids = dataset_train.load_mask(image_id)
    visualize.display_top_masks(image, mask, class_ids, dataset_train.class_names)
# Out:
# [164 121 149  81]
# image_id 164
# image_id 121
# image_id 149
# image_id 81

# %% [markdown]
# ## Create Model

# %%
# Create model in training mode
model = modellib.MaskRCNN(mode="training", config=config,
                          model_dir=MODEL_DIR)

# Which weights to start with?
init_with = "coco"  # imagenet, coco, or last

if init_with == "imagenet":
    model.load_weights(model.get_imagenet_weights(), by_name=True)
elif init_with == "coco":
    # Load weights trained on MS COCO, but skip layers that
    # are different due to the different number of classes
    # See README for instructions to download the COCO weights
    model.load_weights(COCO_MODEL_PATH, by_name=True,
                       exclude=["mrcnn_class_logits", "mrcnn_bbox_fc",
                                "mrcnn_bbox", "mrcnn_mask","conv1"])
elif init_with == "last":
    # Load the last model you trained and continue training
    model.load_weights(model.find_last()[1], by_name=True)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:442: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:58: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:3543: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:3386: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:1768: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:1154: calling reduce_max_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:1188: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/ops/array_ops.py:1475: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/drive/MyDrive/Mask_RCNN/mrcnn/model.py:553: The name tf.random_shuffle is deprecated. Please use tf.random.shuffle instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/Mask_RCNN/mrcnn/utils.py:202: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/Mask_RCNN/mrcnn/model.py:600: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:153: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:158: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:163: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:333: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:341: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.

# %% [markdown]
# ## Training
#
# Train in two stages:
# 1. Only the heads. Here we're freezing all the backbone layers and training only the randomly initialized layers (i.e. the ones that we didn't use pre-trained weights from MS COCO). To train only the head layers, pass `layers='heads'` to the `train()` function.
#
# 2. Fine-tune all layers. For this simple example it's not necessary, but we're including it to show the process. Simply pass `layers="all` to train all layers.

# %%
# Train the head branches
# Passing layers="heads" freezes all layers except the head
# layers. You can also pass a regular expression to select
# which layers to train by name pattern.
model.train(dataset_train, dataset_val,
            learning_rate=config.LEARNING_RATE,
            epochs=30,
            layers='heads')
# Out:
# Starting at epoch 0. LR=0.001
#
# Checkpoint Path: /content/drive/MyDrive/Mask_RCNN/logs/shapes20221122T0329/mask_rcnn_shapes_{epoch:04d}.h5
# Selecting layers to train
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/optimizers.py:711: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:899: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:625: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:886: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/callbacks.py:705: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/callbacks.py:708: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
# Epoch 1/30
# image_id 84
# ERROR:root:Error processing image {'id': 84, 'source': 'shapes', 'path': '/content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/pic/9-17.jpg', 'width': 512, 'height': 512, 'mask_path': '/content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/cv2_mask/9-17.png', 'yaml_path': '/content/drive/MyDrive/CGMH/MaskRCNN-train-my-data/train_data/labelme_json/9-17_json/info.yaml'}
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Mask_RCNN/mrcnn/model.py", line 1774, in data_generator
#     batch_gt_class_ids[b, :gt_class_ids.shape[0]] = gt_class_ids
# ValueError: could not broadcast input array from shape (2,) into shape (1,)
# image_id 51

# %%
# Fine tune all layers
# Passing layers="all" trains all layers. You can also
# pass a regular expression to select which layers to
# train by name pattern.
model.train(dataset_train, dataset_val,
           learning_rate=config.LEARNING_RATE / 10,
           epochs=30,
           layers="all")

# %%
# Save weights
# Typically not needed because callbacks save after every epoch
# Uncomment to save manually
# model_path = os.path.join(MODEL_DIR, "mask_rcnn_shapes.h5")
# model.keras_model.save_weights(model_path)

# %% [markdown]
# ## Detection

# %%
class InferenceConfig(ShapesConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

inference_config = InferenceConfig()

# Recreate the model in inference mode
model = modellib.MaskRCNN(mode="inference", 
                          config=inference_config,
                          model_dir=MODEL_DIR)


# Get path to saved weights
# Either set a specific path or find last trained weights
# model_path = os.path.join(ROOT_DIR, ".h5 file name here")
model_path = model.find_last()

# Load trained weights
print("Loading weights from ", model_path)
model.load_weights(model_path, by_name=True)

# %%
#get from test_model.py
import skimage.io
from datetime import datetime 
# Directory of images to run detection on
IMAGE_DIR = os.path.join(ROOT_DIR, "images")
# COCO Class names
# Index of the class in the list is its ID. For example, to get ID of
# the teddy bear class, use: class_names.index('teddy bear')
class_names = ['BG', 'cylindrical','varicose','cystic']
# Load a random image from the images folder
file_names = next(os.walk(IMAGE_DIR))[2]
image = skimage.io.imread(os.path.join(IMAGE_DIR, random.choice(file_names)))

a=datetime.now() 
# Run detection
results = model.detect([image], verbose=1)
b=datetime.now() 
# Visualize results
print("shijian",(b-a).seconds)
r = results[0]
visualize.display_instances(image, r['rois'], r['masks'], r['class_ids'], 
                            class_names, r['scores'])

# %%
# Test on a random image
image_id = random.choice(dataset_val.image_ids)
original_image, image_meta, gt_class_id, gt_bbox, gt_mask =\
    modellib.load_image_gt(dataset_val, inference_config, 
                           image_id, use_mini_mask=False)

log("original_image", original_image)
log("image_meta", image_meta)
log("gt_class_id", gt_class_id)
log("gt_bbox", gt_bbox)
log("gt_mask", gt_mask)

visualize.display_instances(original_image, gt_bbox, gt_mask, gt_class_id, 
                            dataset_train.class_names, figsize=(8, 8))

# %%
results = model.detect([original_image], verbose=1)

r = results[0]
visualize.display_instances(original_image, r['rois'], r['masks'], r['class_ids'], 
                            dataset_val.class_names, r['scores'], ax=get_ax())

# %% [markdown]
# ## Evaluation

# %%
# Compute VOC-Style mAP @ IoU=0.5
# Running on 10 images. Increase for better accuracy.
image_ids = np.random.choice(dataset_val.image_ids, 10)
APs = []
for image_id in image_ids:
    # Load image and ground truth data
    image, image_meta, gt_class_id, gt_bbox, gt_mask =\
        modellib.load_image_gt(dataset_val, inference_config,
                               image_id, use_mini_mask=False)
    molded_images = np.expand_dims(modellib.mold_image(image, inference_config), 0)
    # Run object detection
    results = model.detect([image], verbose=0)
    r = results[0]
    # Compute AP
    AP, precisions, recalls, overlaps =\
        utils.compute_ap(gt_bbox, gt_class_id, gt_mask,
                         r["rois"], r["class_ids"], r["scores"], r['masks'])
    APs.append(AP)
    
print("mAP: ", np.mean(APs))
